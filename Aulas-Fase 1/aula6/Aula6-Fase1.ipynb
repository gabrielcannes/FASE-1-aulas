# %% [markdown]
# Nesta aula prática, demonstraremos como criar e publicar uma biblioteca no
# PyPI. Exploramos a importância dessa prática para a organização e a reutilização de código, além de aprendermos a criar nossos próprios módulos e bibliotecas de maneira eficiente.

# %% [markdown]
# ONDE?
#
# No pypi (gerenciador de pacotes do python) é onde podemos subir nossas bibliotecas criadas. https://pypi.org
